# %% [markdown]
# ### Predict whether the patient has diabetes using the Pima Indian Diabetes dataset.
#
# The features are:
# 1. Number of times pregnant
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3. Diastolic blood pressure (mm Hg)
# 4. Triceps skin fold thickness (mm)
# 5. 2-Hour serum insulin (mu U/ml)
# 6. Body mass index (weight in kg/(height in m)^2)
# 7. Diabetes pedigree function
# 8. Age (years)
#
# Class label: 0 or 1 for negative for Diabetes or positive

# %%
import numpy as np
import tensorflow as tf
import math
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
from keras import layers
from keras.layers import Input, Dense, Activation, BatchNormalization
from keras.models import Model
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %% [markdown]
# The datafile is imported to Google Drive. Load the file from there.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data_file = '/content/drive/My Drive/MLData/diabetes_data.csv'

dataset = np.genfromtxt(data_file, delimiter=',')

class_labels = dataset[:, -1]
raw_data = dataset[:, :-1]

print("Size of labels : " + str(class_labels.shape))
print("Size of data : " + str(raw_data.shape))

X = raw_data
Y = class_labels
# Out:
# Size of labels : (768,)
# Size of data : (768, 8)

# %% [markdown]
# Define a model. We have 8 features in the input data, that is specified in the input layer. We use ReLU activation for all the hidden layers. Since it is binary classification problem, output layer has sigmoid activation.

# %%
def prediction_model():
  model = Sequential()
  num_nodes = 30
  model.add(Dense(num_nodes, input_dim=8, activation='relu')) #Input layer
  model.add(Dense(num_nodes, activation='relu')) # Hidden layers
  model.add(Dense(num_nodes, activation='relu'))
  model.add(Dense(num_nodes, activation='relu'))
  model.add(Dense(num_nodes, activation='relu'))
  model.add(Dense(num_nodes, activation='relu'))
  model.add(Dense(num_nodes, activation='relu'))
  model.add(Dense(1, activation='sigmoid')) # Output layer
  
  return model

# %% [markdown]
# Use Adam Optimizer with binary cross-entropy loss.

# %%
diabetes_model = prediction_model()

diabetes_model.compile(loss='binary_crossentropy', optimizer="Adam", metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
diabetes_model.fit(x = raw_data , y = Y, epochs = 500, batch_size = 64, validation_split = 0.1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 691 samples, validate on 77 samples
# Epoch 1/500
# 691/691 [==============================] - 1s 1ms/step - loss: 0.6821 - acc: 0.6324 - val_loss: 0.7413 - val_acc: 0.5974
# Epoch 2/500
# 691/691 [==============================] - 0s 33us/step - loss: 0.6178 - acc: 0.6729 - val_loss: 0.6650 - val_acc: 0.6883
# Epoch 3/500
# 691/691 [==============================] - 0s 35us/step - loss: 0.6131 - acc: 0.6816 - val_loss: 0.6640 - val_acc: 0.6623
# Epoch 4/500
# 691/691 [==============================] - 0s 32us/step - loss: 0.5940 - acc: 0.7048 - val_loss: 0.6348 - val_acc: 0.7273
# Epoch 5/500
# 691/691 [==============================] - 0s 31us/step - loss: 0.5876 - acc: 0.7048 - val_loss: 0.6846 - val_acc: 0.5584
# ...

# %% [markdown]
# Show the summary of the model and evaluation of the model

# %%
diabetes_model.summary()
scores = diabetes_model.evaluate(X, Y)
print("\nAccuracy: %.2f%%" % (scores[1]*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 30)                270
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_5 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_7 (Dense)              (None, 30)                930
# ...
